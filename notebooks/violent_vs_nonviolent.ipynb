# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import re
import numpy as np
from datetime import datetime

# %%
df = pd.read_csv(r"C:\Users\kesha\Documents\nss_da10\projects\police-response-capstone\data\Metro_Nashville_Police_Department_Incidents_20240217.csv")

# %%
df.head()
# Out:
#       Primary Key  Incident Number Report Type Report Type Description  \
# 0  20190496213_11      20190496213           D              DISPATCHED
# 1  20180290646_11      20180290646           D              DISPATCHED
# 2  20200243837_11      20200243837           D              DISPATCHED
# 3  20170471747_11      20170471747           D              DISPATCHED
# 4  20171099391_21      20171099391           D              DISPATCHED
#
#   Incident Status Code Incident Status Description Investigation Status  \
# 0                    U                   UNFOUNDED               Closed
# 1                    A           CLEARED BY ARREST               Closed
# 2                    U                   UNFOUNDED               Closed
# 3                    U                   UNFOUNDED               Closed
# 4                    A           CLEARED BY ARREST               Closed
#
#   Incident Occurred Incident Reported Incident Location  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 865175 entries, 0 to 865174
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Primary Key                  865175 non-null  object
#  1   Incident Number              865175 non-null  int64
#  2   Report Type                  865089 non-null  object
#  3   Report Type Description      805823 non-null  object
#  4   Incident Status Code         865155 non-null  object
#  5   Incident Status Description  865145 non-null  object
#  6   Investigation Status         865175 non-null  object
#  7   Incident Occurred            865175 non-null  object
#  8   Incident Reported            865175 non-null  object
#  9   Incident Location            859872 non-null  object
#  10  Latitude                     848238 non-null  float64
#  11  Longitude                    848238 non-null  float64
# ...

# %%
officers = df[['Report Type Description','Offense Description','Investigation Status','Incident Occurred','Incident Reported','ZIP Code']]
officers
# Out:
#        Report Type Description           Offense Description  \
# 0                   DISPATCHED                POLICE INQUIRY
# 1                   DISPATCHED                   SHOPLIFTING
# 2                   DISPATCHED                POLICE INQUIRY
# 3                   DISPATCHED                    CIVIL CASE
# 4                   DISPATCHED          BURGLARY- AGGRAVATED
# ...                        ...                           ...
# 865170              DISPATCHED                     TRANSPORT
# 865171              DISPATCHED       BURGLARY- MOTOR VEHICLE
# 865172              DISPATCHED       BURGLARY- MOTOR VEHICLE
# 865173              DISPATCHED  ROBBERY, AGGRAVATED, HANDGUN
# 865174              DISPATCHED     RECOVERY, STOLEN PROPERTY
#
#        Investigation Status Incident Occurred Incident Reported  ZIP Code
# 0                    Closed    7/1/2019 17:31    7/1/2019 18:17   37214.0
# 1                    Closed   3/31/2018 12:21   3/31/2018 19:41   37013.0
# ...

# %%
mnpd_officers = officers.loc[officers['Report Type Description'] == "DISPATCHED"]
mnpd_officers
# Out:
#        Report Type Description           Offense Description  \
# 0                   DISPATCHED                POLICE INQUIRY
# 1                   DISPATCHED                   SHOPLIFTING
# 2                   DISPATCHED                POLICE INQUIRY
# 3                   DISPATCHED                    CIVIL CASE
# 4                   DISPATCHED          BURGLARY- AGGRAVATED
# ...                        ...                           ...
# 865170              DISPATCHED                     TRANSPORT
# 865171              DISPATCHED       BURGLARY- MOTOR VEHICLE
# 865172              DISPATCHED       BURGLARY- MOTOR VEHICLE
# 865173              DISPATCHED  ROBBERY, AGGRAVATED, HANDGUN
# 865174              DISPATCHED     RECOVERY, STOLEN PROPERTY
#
#        Investigation Status Incident Occurred Incident Reported  ZIP Code
# 0                    Closed    7/1/2019 17:31    7/1/2019 18:17   37214.0
# 1                    Closed   3/31/2018 12:21   3/31/2018 19:41   37013.0
# ...

# %%
npd_officers = mnpd_officers.loc[officers['Investigation Status'] == "Closed"]
npd_officers
# Out:
#        Report Type Description             Offense Description  \
# 0                   DISPATCHED                  POLICE INQUIRY
# 1                   DISPATCHED                     SHOPLIFTING
# 2                   DISPATCHED                  POLICE INQUIRY
# 3                   DISPATCHED                      CIVIL CASE
# 4                   DISPATCHED            BURGLARY- AGGRAVATED
# ...                        ...                             ...
# 865161              DISPATCHED                    SIMPLE ASSLT
# 865164              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 865167              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 865168              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 865170              DISPATCHED                       TRANSPORT
#
#        Investigation Status Incident Occurred Incident Reported  ZIP Code
# 0                    Closed    7/1/2019 17:31    7/1/2019 18:17   37214.0
# ...

# %%
npd_officers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 362799 entries, 0 to 865170
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Report Type Description  362799 non-null  object
#  1   Offense Description      362799 non-null  object
#  2   Investigation Status     362799 non-null  object
#  3   Incident Occurred        362799 non-null  object
#  4   Incident Reported        362799 non-null  object
#  5   ZIP Code                 362045 non-null  float64
# dtypes: float64(1), object(5)
# memory usage: 19.4+ MB

# %%
npd_officers['Incident Occurred'] = npd_officers['Incident Occurred'].astype("string")
npd_officers['Incident Reported'] = npd_officers['Incident Reported'].astype("string")
# Out:
# C:\Users\kesha\AppData\Local\Temp\ipykernel_30140\1760736431.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   npd_officers['Incident Occurred'] = npd_officers['Incident Occurred'].astype("string")
# C:\Users\kesha\AppData\Local\Temp\ipykernel_30140\1760736431.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   npd_officers['Incident Reported'] = npd_officers['Incident Reported'].astype("string")

# %%
npd_officers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 362799 entries, 0 to 865170
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Report Type Description  362799 non-null  object
#  1   Offense Description      362799 non-null  object
#  2   Investigation Status     362799 non-null  object
#  3   Incident Occurred        362799 non-null  string
#  4   Incident Reported        362799 non-null  string
#  5   ZIP Code                 362045 non-null  float64
# dtypes: float64(1), object(3), string(2)
# memory usage: 19.4+ MB

# %%
npd_officers_clean = npd_officers.reset_index()

# %%
npd_officers_clean
# Out:
#          index Report Type Description             Offense Description  \
# 0            0              DISPATCHED                  POLICE INQUIRY
# 1            1              DISPATCHED                     SHOPLIFTING
# 2            2              DISPATCHED                  POLICE INQUIRY
# 3            3              DISPATCHED                      CIVIL CASE
# 4            4              DISPATCHED            BURGLARY- AGGRAVATED
# ...        ...                     ...                             ...
# 362794  865161              DISPATCHED                    SIMPLE ASSLT
# 362795  865164              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362796  865167              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362797  865168              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362798  865170              DISPATCHED                       TRANSPORT
#
#        Investigation Status Incident Occurred Incident Reported  ZIP Code
# ...

# %%
npd_officers_cleaner = npd_officers_clean.drop(columns=['index'])

# %%
npd_officers_cleaner
# Out:
#        Report Type Description             Offense Description  \
# 0                   DISPATCHED                  POLICE INQUIRY
# 1                   DISPATCHED                     SHOPLIFTING
# 2                   DISPATCHED                  POLICE INQUIRY
# 3                   DISPATCHED                      CIVIL CASE
# 4                   DISPATCHED            BURGLARY- AGGRAVATED
# ...                        ...                             ...
# 362794              DISPATCHED                    SIMPLE ASSLT
# 362795              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362796              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362797              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362798              DISPATCHED                       TRANSPORT
#
#        Investigation Status Incident Occurred Incident Reported  ZIP Code
# 0                    Closed    7/1/2019 17:31    7/1/2019 18:17   37214.0
# ...

# %%
npd_officers_cleaner['Incident Reported Datetime'] = pd.to_datetime(npd_officers_cleaner['Incident Reported'])
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 npd_officers_cleaner['Incident Reported Datetime'] = pd.to_datetime(npd_officers_cleaner['Incident Reported'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1050, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048         result = arg.map(cache_array)
#    1049     else:
# -> 1050         values = convert_listlike(arg._values, format)
#    1051         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
npd_officers_cleanest = npd_officers_cleaner.drop(295058)

# %%
npd_officers_cleanest
# Out:
#        Report Type Description             Offense Description  \
# 0                   DISPATCHED                  POLICE INQUIRY
# 1                   DISPATCHED                     SHOPLIFTING
# 2                   DISPATCHED                  POLICE INQUIRY
# 3                   DISPATCHED                      CIVIL CASE
# 4                   DISPATCHED            BURGLARY- AGGRAVATED
# ...                        ...                             ...
# 362794              DISPATCHED                    SIMPLE ASSLT
# 362795              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362796              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362797              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362798              DISPATCHED                       TRANSPORT
#
#        Investigation Status Incident Occurred Incident Reported  ZIP Code
# 0                    Closed    7/1/2019 17:31    7/1/2019 18:17   37214.0
# ...

# %%
npd_officers_cleaner['Incident Reported Datetime'] = pd.to_datetime(npd_officers_cleaner['Incident Reported'])
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 npd_officers_cleaner['Incident Reported Datetime'] = pd.to_datetime(npd_officers_cleaner['Incident Reported'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1050, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048         result = arg.map(cache_array)
#    1049     else:
# -> 1050         values = convert_listlike(arg._values, format)
#    1051         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
npd_officers_cleanest = npd_officers_cleaner.drop(295059)

# %%
npd_officers_cleanest['Incident Reported Datetime'] = pd.to_datetime(npd_officers_cleanest['Incident Reported'])

# %%
npd_officers_cleanest['Incident Occurred Datetime'] = pd.to_datetime(npd_officers_cleanest['Incident Occurred'])

# %%
npd_officers_cleanest
# Out:
#        Report Type Description             Offense Description  \
# 0                   DISPATCHED                  POLICE INQUIRY
# 1                   DISPATCHED                     SHOPLIFTING
# 2                   DISPATCHED                  POLICE INQUIRY
# 3                   DISPATCHED                      CIVIL CASE
# 4                   DISPATCHED            BURGLARY- AGGRAVATED
# ...                        ...                             ...
# 362794              DISPATCHED                    SIMPLE ASSLT
# 362795              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362796              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362797              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362798              DISPATCHED                       TRANSPORT
#
#        Investigation Status Incident Occurred Incident Reported  ZIP Code  \
# 0                    Closed    7/1/2019 17:31    7/1/2019 18:17   37214.0
# ...

# %%
npd_officers_cleanest['occurred_year'] = npd_officers_cleanest['Incident Occurred Datetime'].dt.year
npd_officers_cleanest['occurred_hour_minutes'] = npd_officers_cleanest['Incident Occurred Datetime'].dt.strftime('%H:%M')

# %%
npd_officers_cleanest['reported_year'] = npd_officers_cleanest['Incident Reported Datetime'].dt.year
npd_officers_cleanest['reported_hour_minutes'] = npd_officers_cleanest['Incident Reported Datetime'].dt.strftime('%H:%M')

# %%
npd_officers_cleanest
# Out:
#        Report Type Description             Offense Description  \
# 0                   DISPATCHED                  POLICE INQUIRY
# 1                   DISPATCHED                     SHOPLIFTING
# 2                   DISPATCHED                  POLICE INQUIRY
# 3                   DISPATCHED                      CIVIL CASE
# 4                   DISPATCHED            BURGLARY- AGGRAVATED
# ...                        ...                             ...
# 362794              DISPATCHED                    SIMPLE ASSLT
# 362795              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362796              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362797              DISPATCHED  ASSAULT- FEAR OF BODILY INJURY
# 362798              DISPATCHED                       TRANSPORT
#
#        Investigation Status Incident Occurred Incident Reported  ZIP Code  \
# 0                    Closed    7/1/2019 17:31    7/1/2019 18:17   37214.0
# ...

# %%
npd_officers_cleanest['Occurred Time'] = pd.to_datetime(npd_officers_cleanest['occurred_hour_minutes'])
# Out:
# C:\Users\kesha\AppData\Local\Temp\ipykernel_30140\3304997610.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   npd_officers_cleanest['Occurred Time'] = pd.to_datetime(npd_officers_cleanest['occurred_hour_minutes'])

# %%
npd_officers_cleanest['Reported Time'] = pd.to_datetime(npd_officers_cleanest['reported_hour_minutes'])
# Out:
# C:\Users\kesha\AppData\Local\Temp\ipykernel_30140\1964612973.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   npd_officers_cleanest['Reported Time'] = pd.to_datetime(npd_officers_cleanest['reported_hour_minutes'])

# %%
npd_officers_cleanest['Time Taken'] = npd_officers_cleanest['Occurred Time'] - npd_officers_cleanest['Reported Time']

# %%
npd_officers_cleanest.loc[npd_officers_cleanest['reported_year'] == 2023]
# Out:
#        Report Type Description               Offense Description  \
# 83                  DISPATCHED                    POLICE INQUIRY
# 1523                DISPATCHED                     LOST PROPERTY
# 2134                DISPATCHED    INTENTIONAL AGGRAVATED ASSAULT
# 2188                DISPATCHED                     LOST PROPERTY
# 2270                DISPATCHED                     LOST PROPERTY
# ...                        ...                               ...
# 362785              DISPATCHED  WEAPON OFFENSE, CRIMINAL ATTEMPT
# 362789              DISPATCHED                    FOUND PROPERTY
# 362791              DISPATCHED                    POLICE INQUIRY
# 362793              DISPATCHED    ASSAULT- FEAR OF BODILY INJURY
# 362796              DISPATCHED    ASSAULT- FEAR OF BODILY INJURY
#
#        Investigation Status Incident Occurred Incident Reported  ZIP Code  \
# 83                   Closed    6/1/2023 18:30    6/1/2023 19:40   37072.0
# ...

# %%
npd_officers_cleanest['Minutes Taken'] = npd_officers_cleanest['Time Taken'] / pd.to_timedelta(1, unit='minute')

# %%
npd_officers_cleanest.loc[npd_officers_cleanest['reported_year'] == 2023]
# Out:
#        Report Type Description               Offense Description  \
# 83                  DISPATCHED                    POLICE INQUIRY
# 1523                DISPATCHED                     LOST PROPERTY
# 2134                DISPATCHED    INTENTIONAL AGGRAVATED ASSAULT
# 2188                DISPATCHED                     LOST PROPERTY
# 2270                DISPATCHED                     LOST PROPERTY
# ...                        ...                               ...
# 362785              DISPATCHED  WEAPON OFFENSE, CRIMINAL ATTEMPT
# 362789              DISPATCHED                    FOUND PROPERTY
# 362791              DISPATCHED                    POLICE INQUIRY
# 362793              DISPATCHED    ASSAULT- FEAR OF BODILY INJURY
# 362796              DISPATCHED    ASSAULT- FEAR OF BODILY INJURY
#
#        Investigation Status Incident Occurred Incident Reported  ZIP Code  \
# 83                   Closed    6/1/2023 18:30    6/1/2023 19:40   37072.0
# ...

# %%
npd_officers_ultra = npd_officers_cleanest.drop(columns=['Report Type Description', 'Investigation Status'])

# %%
crime_times = npd_officers_ultra.groupby(by='Offense Description')['Minutes Taken'].mean()

# %%
crime_times.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 400 entries, ACCIDENTAL INJURY to Weapon - Felon-Poss-Firearm (Force,Violence,Deadly Weapon)
# Series name: Minutes Taken
# Non-Null Count  Dtype
# --------------  -----
# 400 non-null    float64
# dtypes: float64(1)
# memory usage: 22.4+ KB

# %%
crime_times
# Out:
# Offense Description
# ACCIDENTAL INJURY                                                9.542133
# ADVERTISING COMMERCIAL SEXUAL ABUSE OF A MINOR                1097.000000
# AGGRAV ASSLT - FAMILY-GUN                                       11.829832
# AGGRAV ASSLT - FAMILY-STGARM                                   209.823529
# AGGRAV ASSLT - FAMILY-WEAPON                                    13.224026
#                                                                  ...
# WORTHLESS CHECK- $2,500 OR > BUT < $10,000                      33.000000
# WORTHLESS CHECK- > $500 BUT < $1,000                             0.000000
# Weapon - Dangerous Felony - w/prior conviction                   7.451389
# Weapon - Felon-Poss-Firearm (Drug Offense)                      32.648855
# Weapon - Felon-Poss-Firearm (Force,Violence,Deadly Weapon)     -32.352941
# Name: Minutes Taken, Length: 400, dtype: float64

# %%
crime_time_hour = crime_times/60

# %%
crime_time_true_hour = crime_time_hour.abs()

# %%
print(crime_time_true_hour.to_string())
# Out:
# Offense Description
# ACCIDENTAL INJURY                                                     0.159036
# ADVERTISING COMMERCIAL SEXUAL ABUSE OF A MINOR                       18.283333
# AGGRAV ASSLT - FAMILY-GUN                                             0.197164
# AGGRAV ASSLT - FAMILY-STGARM                                          3.497059
# AGGRAV ASSLT - FAMILY-WEAPON                                          0.220400
# AGGRAV ASSLT - GUN                                                    1.550000
# AGGRAV ASSLT - NONFAMILY-GUN                                          1.416968
# AGGRAV ASSLT - NONFAMILY-STGARM                                       1.019048
# AGGRAV ASSLT - NONFAMILY-WEAPON                                       0.130577
# AGGRAV ASSLT - POL OFF-GUN                                            0.822951
# AGGRAV ASSLT - POL OFF-STGARM                                         0.833333
# AGGRAV ASSLT - POL OFF-WEAPON                                         0.975694
# ...

# %%
boom = crime_time_true_hour.to_frame().reset_index()

# %%
big_boom = boom.rename(columns= {0: 'list'})
big_boom.index.name = 'index'

# %%
big_boom
# Out:
#                                      Offense Description  Minutes Taken
# index
# 0                                      ACCIDENTAL INJURY       0.159036
# 1         ADVERTISING COMMERCIAL SEXUAL ABUSE OF A MINOR      18.283333
# 2                              AGGRAV ASSLT - FAMILY-GUN       0.197164
# 3                           AGGRAV ASSLT - FAMILY-STGARM       3.497059
# 4                           AGGRAV ASSLT - FAMILY-WEAPON       0.220400
# ...                                                  ...            ...
# 395           WORTHLESS CHECK- $2,500 OR > BUT < $10,000       0.550000
# 396                 WORTHLESS CHECK- > $500 BUT < $1,000       0.000000
# 397       Weapon - Dangerous Felony - w/prior conviction       0.124190
# 398           Weapon - Felon-Poss-Firearm (Drug Offense)       0.544148
# 399    Weapon - Felon-Poss-Firearm (Force,Violence,De...       0.539216
#
# [400 rows x 2 columns]

# %%
big_boom['Hours Taken'] = big_boom['Minutes Taken']

# %%
big_boom
# Out:
#                                      Offense Description  Minutes Taken  \
# index
# 0                                      ACCIDENTAL INJURY       0.159036
# 1         ADVERTISING COMMERCIAL SEXUAL ABUSE OF A MINOR      18.283333
# 2                              AGGRAV ASSLT - FAMILY-GUN       0.197164
# 3                           AGGRAV ASSLT - FAMILY-STGARM       3.497059
# 4                           AGGRAV ASSLT - FAMILY-WEAPON       0.220400
# ...                                                  ...            ...
# 395           WORTHLESS CHECK- $2,500 OR > BUT < $10,000       0.550000
# 396                 WORTHLESS CHECK- > $500 BUT < $1,000       0.000000
# 397       Weapon - Dangerous Felony - w/prior conviction       0.124190
# 398           Weapon - Felon-Poss-Firearm (Drug Offense)       0.544148
# 399    Weapon - Felon-Poss-Firearm (Force,Violence,De...       0.539216
#
#        Hours Taken
# index
# 0         0.159036
# 1        18.283333
# 2         0.197164
# ...

# %%
blam =big_boom.drop(columns=['Minutes Taken'])

# %%
blam
# Out:
#                                      Offense Description  Hours Taken
# index
# 0                                      ACCIDENTAL INJURY     0.159036
# 1         ADVERTISING COMMERCIAL SEXUAL ABUSE OF A MINOR    18.283333
# 2                              AGGRAV ASSLT - FAMILY-GUN     0.197164
# 3                           AGGRAV ASSLT - FAMILY-STGARM     3.497059
# 4                           AGGRAV ASSLT - FAMILY-WEAPON     0.220400
# ...                                                  ...          ...
# 395           WORTHLESS CHECK- $2,500 OR > BUT < $10,000     0.550000
# 396                 WORTHLESS CHECK- > $500 BUT < $1,000     0.000000
# 397       Weapon - Dangerous Felony - w/prior conviction     0.124190
# 398           Weapon - Felon-Poss-Firearm (Drug Offense)     0.544148
# 399    Weapon - Felon-Poss-Firearm (Force,Violence,De...     0.539216
#
# [400 rows x 2 columns]

# %%
print(blam.to_string())
# Out:
#                                                      Offense Description  Hours Taken
# index
# 0                                                      ACCIDENTAL INJURY     0.159036
# 1                         ADVERTISING COMMERCIAL SEXUAL ABUSE OF A MINOR    18.283333
# 2                                              AGGRAV ASSLT - FAMILY-GUN     0.197164
# 3                                           AGGRAV ASSLT - FAMILY-STGARM     3.497059
# 4                                           AGGRAV ASSLT - FAMILY-WEAPON     0.220400
# 5                                                     AGGRAV ASSLT - GUN     1.550000
# 6                                           AGGRAV ASSLT - NONFAMILY-GUN     1.416968
# 7                                        AGGRAV ASSLT - NONFAMILY-STGARM     1.019048
# 8                                        AGGRAV ASSLT - NONFAMILY-WEAPON     0.130577
# 9                                             AGGRAV ASSLT - POL OFF-GUN     0.822951
# ...

# %%
#wanted this dataframe to be a csv so I could play around with it in power bi, not necessarily what I was going for due to the nature of the crimes. Too many offense descriptions to properly graph them.
blam.to_csv("../data/blam.csv", index=True)

# %%
blam.loc[[0,1],'Hours Taken'].mean()
# Out:
# 9.221184439473031

# %%
blam['Hours Taken'].mean()
# Out:
# 2.5153028829847695
