# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import re
import numpy as np

# %%
race_df = pd.read_excel(r"C:\Users\kesha\Documents\nss_da10\projects\police-response-capstone\data\race_per_zipcode_nashville.xlsx")

# %%
race_df
# Out:
#                                                B02001              Race  \
# 0                                                 NaN  All of Nashville
# 1                                                 NaN             Value
# 2                                              Total:                 1
# 3                                         White alone          0.591341
# 4                     Black or African American alone          0.268085
# 5             American Indian and Alaska Native alone            0.0014
# 6                                         Asian alone          0.036285
# 7    Native Hawaiian and Other Pacific Islander alone          0.000523
# 8                               Some Other Race alone          0.038354
# 9                                  Two or More Races:          0.064011
# 10                Two races including Some Other Race          0.033761
# 11  Two races excluding Some Other Race, and three...           0.03025
# ...

# %%
race_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 42 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   B02001       11 non-null     object
#  1   Race         12 non-null     object
#  2   Unnamed: 2   12 non-null     object
#  3   Unnamed: 3   12 non-null     object
#  4   Unnamed: 4   12 non-null     object
#  5   Unnamed: 5   12 non-null     object
#  6   Unnamed: 6   12 non-null     object
#  7   Unnamed: 7   12 non-null     object
#  8   Unnamed: 8   12 non-null     object
#  9   Unnamed: 9   12 non-null     object
#  10  Unnamed: 10  12 non-null     object
#  11  Unnamed: 11  12 non-null     object
#  12  Unnamed: 12  12 non-null     object
#  13  Unnamed: 13  12 non-null     object
#  14  Unnamed: 14  12 non-null     object
#  15  Unnamed: 15  12 non-null     object
#  16  Unnamed: 16  12 non-null     object
#  17  Unnamed: 17  12 non-null     object
# ...

# %%
race_df.columns = race_df.iloc[0]
race_df
# Out:
# 0                                                 NaN  All of Nashville  \
# 0                                                 NaN  All of Nashville
# 1                                                 NaN             Value
# 2                                              Total:                 1
# 3                                         White alone          0.591341
# 4                     Black or African American alone          0.268085
# 5             American Indian and Alaska Native alone            0.0014
# 6                                         Asian alone          0.036285
# 7    Native Hawaiian and Other Pacific Islander alone          0.000523
# 8                               Some Other Race alone          0.038354
# 9                                  Two or More Races:          0.064011
# 10                Two races including Some Other Race          0.033761
# 11  Two races excluding Some Other Race, and three...           0.03025
# ...

# %%
#Getting rid of rows that I did not need 
w_race_df = race_df.drop([0,1,2,4,5,6,7,8,9,10,11,12])

# %%
pd.set_option('display.max_columns', None)

# %%
w_race_df
# Out:
# 0          NaN All of Nashville    37013     37015     37027     37062  \
# 3  White alone         0.591341  0.42983  0.930695  0.837353  0.887525
#
# 0     37064     37072     37073     37075     37076     37080     37082  \
# 3  0.834885  0.686843  0.936276  0.847771  0.640898  0.814382  0.917588
#
# 0     37086    37115     37122     37135     37138     37143     37172  \
# 3  0.530975  0.42773  0.832983  0.832503  0.826544  0.957238  0.724698
#
# 0     37189     37201     37203     37204     37205     37206    37207  \
# 3  0.484658  0.714559  0.629212  0.806951  0.915211  0.641703  0.28876
#
# 0     37208     37209     37210     37211     37212 37213     37214     37215  \
# 3  0.342577  0.679903  0.483373  0.614688  0.734139     0  0.663045  0.860663
#
# 0     37216    37217     37218    37219     37220     37221     37228
# 3  0.701837  0.51202  0.224347  0.93785  0.929303  0.826037  0.315331
